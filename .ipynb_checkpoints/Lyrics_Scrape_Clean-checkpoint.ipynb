# %% [markdown]
# ## Scrape lyrics of two or more artists and predict the artist using Multinomial Naive Bayes Model

# %% [markdown]
# ### 1. Import relevant packages

# %%
import nlp_scrape_lyrics

import requests
import re
from bs4 import BeautifulSoup as bs# import beautiful soup = bs
import spacy

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import wordcloud

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# ### 2. Construct complete URL and create list of complete URL's and titles

# %%
result_amy, titles_amy= nlp_scrape_lyrics.get_artists_link('https://www.lyrics.com/artist/Amy+Winehouse/612371', 'Amy+Winehouse')
result_adele, titles_adele= nlp_scrape_lyrics.get_artists_link('https://www.lyrics.com/artist/Adele/861756', 'Adele')
result_cardi, titles_cardi= nlp_scrape_lyrics.get_artists_link('https://www.lyrics.com/artist/Cardi+B/3195462', 'Cardi+B')

# %% [markdown]
# ### 3. Download and spacify lyrics and zip to titles

# %% [markdown]
# #### 3.1 Define customized stopwords

# %%
customize_stop_words = ['don', 've', 'll', 'ain', 't', 's', 'm', 'd', 're']

# %% [markdown]
# #### 3.2 Scrape and preprocess lyrics and append them to a dataframe including artist and songtitle

# %%
adele_df, adele_list, adele_spacy= nlp_scrape_lyrics.get_lyrics(result_adele, titles_adele, 'Adele', customize_stop_words, totext= True)
amy_df, amy_list, amy_spacy= nlp_scrape_lyrics.get_lyrics(result_amy, titles_amy, 'AmyD', customize_stop_words)
cardi_df, cardi_list, cardi_spacy= nlp_scrape_lyrics.get_lyrics(result_cardi, titles_cardi, 'CardiB', customize_stop_words)

# %% [markdown]
# ### 4. Generate Wordcloud

# %%
amy_songs= ' '.join(amy_spacy)
adele_songs= ' '.join(adele_spacy)
cardi_songs= ' '.join(cardi_spacy)

mask = np.zeros((500, 500, 3), np.uint8)
mask[50:70, 50:70,:] = 255  # masked out area
cloud = wordcloud.WordCloud(background_color="white",
                max_words=50,
                mask=mask,
                collocations= False,  # calculates frequencies
                contour_color='steelblue').generate(amy_songs)
                # stop words are removed!

plt.figure(figsize = (10,10))
plt.imshow(cloud, interpolation='bilinear')
plt.savefig('cloud.png')
plt.show()

# %%
cloud = wordcloud.WordCloud(background_color="white",
                max_words=50,
                mask=mask,
                collocations= False,  # calculates frequencies
                contour_color='steelblue').generate(adele_songs)
                # stop words are removed!

plt.figure(figsize = (10,10))
plt.imshow(cloud, interpolation='bilinear')
plt.savefig('cloud.png')
plt.show()

# %%
cloud = wordcloud.WordCloud(background_color="white",
                max_words=50,
                mask=mask,
                collocations= False,  # calculates frequencies
                contour_color='steelblue').generate(cardi_songs)
                # stop words are removed!

plt.figure(figsize = (10,10))
plt.imshow(cloud, interpolation='bilinear')
plt.savefig('cloud.png')
plt.show()

# %% [markdown]
# ### 5. Drop duplicate songs and concat df's

# %%
amy_df.drop(amy_df.index[[5, 21, 25, 37, 19]], inplace= True)
master= pd.concat([amy_df, adele_df], ignore_index= True)

# %% [markdown]
# ### 6. Train-test-split

# %%
X= master['spacified_lyric']
y= master['artist']

Xtrain, Xtest, ytrain, ytest= train_test_split(X,y,random_state=42)

# %% [markdown]
# ### 7. Apply Vectorization and TF-IDF transformation to Xtrain and Xtest

# %%
cv = CountVectorizer(min_df= 5)
Xtrain_cv= cv.fit_transform(Xtrain)
tf= TfidfTransformer()
Xtrain_tf= tf.fit_transform(Xtrain_cv)

# %%
Xtest_cv= cv.transform(Xtest)
Xtest_tf= tf.transform(Xtest_cv)

# %% [markdown]
# ### 8. Fit a Multinomial Naive Bayes model on our transformed vector (X) and our artist labels (y) and predict artists with Xtest

# %%
m = MultinomialNB(alpha= 2.0)
m.fit(Xtrain_tf, ytrain)
ypred= m.predict(Xtest_tf) #predictions
proba= m.predict_proba(Xtest_tf) #probabilities

# %% [markdown]
# ### 9. Which words in the data were the most important?

# %%
prob_log = m.feature_log_prob_
diff = prob_log[0] - prob_log[1] 

sns.set(font_scale=1.5)
# %matplotlib inline
imp= pd.DataFrame(data=diff, index=sorted(cv.vocabulary_.keys())).sort_values(by=0)
imp.iloc[np.r_[0:5, -5:0]]
# Out:
#               0
# man   -1.057188
# come  -0.692492
# bed   -0.472840
# bout  -0.427936
# get   -0.417411
# word   0.460622
# give   0.496989
# heart  0.505646
# feel   0.508792
# wish   0.529837

# %% [markdown]
# ### 10. Create prediction dataframe

# %%
compare= pd.DataFrame(zip(list(ytest), list(Xtest), list(proba[:,0]), list(proba[:,1])), index= list(ypred), columns= ['actual_artist', 'lyrics', 'proba_adele', 'proba_amy'])

# %%
compare.head()
# Out:
#       actual_artist                                             lyrics  \
# AmyD           AmyD  meet downstairs bar hear   roll sleeve skull s...
# AmyD           AmyD  attract   till hurt concentrate    distract   ...
# AmyD           AmyD  man fight   unholy war     straight shake   st...
# Adele          AmyD  leave time regret   keep lip wet   old safe be...
# AmyD           AmyD  time   friend      safe   evening    cause dri...
#
#        proba_adele  proba_amy
# AmyD      0.479168   0.520832
# AmyD      0.482005   0.517995
# AmyD      0.436677   0.563323
# Adele     0.642923   0.357077
# AmyD      0.486763   0.513237

# %% [markdown]
# ### 11. Calculate train and test scores

# %%
m.score(Xtest_tf, list(ytest))
# Out:
# 0.65

# %%
m.score(Xtrain_tf, list(ytrain))
# Out:
# 0.9152542372881356
